# %%
# %%

from nltk import Prover9, Prover9Command
from nltk.sem import Expression

read_expr = Expression.fromstring

p = Prover9()
p._binary_location = r"C:\Program Files (x86)\Prover9-Mace4\bin-win32"

# %%
# %%

assumptions = [
    read_expr(p)
    for p in [
        # Every child loves Santa.
        """
        all x.(child(x) -> loves(x,Santa))
        """,
        # Everyone who loves Santa loves any reindeer.
        """
        all x.(loves(x,Santa) -> (all y.( reindeer(y) -> loves(x,y))))
        """,
        # Rudolph is a reindeer, and Rudolph has a red nose.
        """
        reindeer(Rudolph) & has_rednose(Rudolph)
        """,
        # Anything which has a red nose is weird or is a clown.
        """
        all x.(has_rednose(x) -> weird(x) | clown(x))
        """,
        # No reindeer is a clown.
        """
        -exists x.(reindeer(x) & clown(x))
        """,
        # Scrooge does not love anything which is weird.
        """
        all x.(weird(x) -> -loves(Scrooge,x))
        """,
    ]
]

goal = read_expr(
    # Scrooge is not a child.
    """
    -child(Scrooge)
    """
)

# %%
# %%

prover = Prover9Command(goal=goal, assumptions=assumptions, prover=p)

prover.print_assumptions()

print()
is_proved = prover.prove()

if is_proved:
    print("It can be proved.\nSee below:\n")
    print(prover.proof())
else:
    print("It cannot be proved")
# Out:
# all x.(child(x) -> loves(x,Santa))
# all x.(loves(x,Santa) -> all y.(reindeer(y) -> loves(x,y)))
# (reindeer(Rudolph) & has_rednose(Rudolph))
# all x.(has_rednose(x) -> (weird(x) | clown(x)))
# -exists x.(reindeer(x) & clown(x))
# all x.(weird(x) -> -loves(Scrooge,x))
#
# It can be proved.
# See below:
#
# ============================== prooftrans ============================
# Prover9 (32) version Dec-2007, Dec 2007.
# Process 14644 was started by Prajwal on Prajwal,
# Wed Apr 10 14:44:53 2024
# The command was "/cygdrive/c/Program Files (x86)/Prover9-Mace4/bin-win32/prover9".
# ============================== end of head ===========================
#
# ============================== end of input ==========================
#
# ============================== PROOF =================================
#
# % -------- Comments from original proof --------
# % Proof 1 at 0.00 (+ 0.01) seconds.
# % Length of proof is 23.
# % Level of proof is 5.
# % Maximum clause weight is 6.
# % Given clauses 2.
#
# 1 (all x (child(x) -> loves(x,Santa))).  [assumption].
# 2 (all x (loves(x,Santa) -> (all y (reindeer(y) -> loves(x,y))))).  [assumption].
# 3 reindeer(Rudolph) & has_rednose(Rudolph).  [assumption].
# 4 (all x (has_rednose(x) -> weird(x) | clown(x))).  [assumption].
# 5 -(exists x (reindeer(x) & clown(x))).  [assumption].
# 6 (all x (weird(x) -> -loves(Scrooge,x))).  [assumption].
# 7 -child(Scrooge).  [goal].
# 8 child(Scrooge).  [deny(7)].
# 9 -child(x) | loves(x,Santa).  [clausify(1)].
# 10 reindeer(Rudolph).  [clausify(3)].
# 11 -loves(x,Santa) | -reindeer(y) | loves(x,y).  [clausify(2)].
# 12 -reindeer(x) | -clown(x).  [clausify(5)].
# 13 -has_rednose(x) | weird(x) | clown(x).  [clausify(4)].
# 14 has_rednose(Rudolph).  [clausify(3)].
# 15 weird(Rudolph) | clown(Rudolph).  [resolve(13,a,14,a)].
# 16 -weird(x) | -loves(Scrooge,x).  [clausify(6)].
# 17 clown(Rudolph) | -loves(Scrooge,Rudolph).  [resolve(15,a,16,a)].
# 18 -clown(Rudolph).  [resolve(12,a,10,a)].
# 19 loves(Scrooge,Santa).  [resolve(8,a,9,a)].
# 20 -loves(x,Santa) | loves(x,Rudolph).  [resolve(10,a,11,b)].
# 21 -loves(Scrooge,Rudolph).  [resolve(17,a,18,a)].
# 22 loves(Scrooge,Rudolph).  [ur(20,a,19,a)].
# 23 $F.  [resolve(22,a,21,a)].
#
# ============================== end of proof ==========================
